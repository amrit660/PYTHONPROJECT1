# %% [markdown]
# <a href="https://colab.research.google.com/github/amrit660/PYTHONPROJECT1/blob/main/cleanprogramme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# clean_shopping.ipynb content (single cell)
print("=== Shopping List Manager (CLEAN) ===")

# Individual item variables (up to 10) - this follows the 'individual string variables' constraint
item1 = ""
item2 = ""
item3 = ""
item4 = ""
item5 = ""
item6 = ""
item7 = ""
item8 = ""
item9 = ""
item10 = ""

# Put the individual variables into a list for easier processing with while loops.
# Note: items themselves remain stored as separate string variables; the list simply references them.
items_vars = ["item1","item2","item3","item4","item5","item6","item7","item8","item9","item10"]

# We will update the variables via indices and a helper mapping approach using while loops.
# (No functions, no dictionaries — only allowed constructs.)

running = True

def _debug_show_vars():
    # This small debug helper is only for clarity while editing; comment out if not allowed.
    pass

while running:
    print("\n1. Add item")
    print("2. View items")
    print("3. Remove item")
    print("4. Count items")
    print("5. Exit")
    choice = input("Choose option: ").strip()

    if choice == "1":  # Add item
        new_item = input("Enter item: ").strip()
        placed = False
        i = 0
        # iterate through indices using while loop to find first empty slot
        while i < 10:
            if i == 0 and item1 == "":
                item1 = new_item
                placed = True
                break
            if i == 1 and item2 == "":
                item2 = new_item
                placed = True
                break
            if i == 2 and item3 == "":
                item3 = new_item
                placed = True
                break
            if i == 3 and item4 == "":
                item4 = new_item
                placed = True
                break
            if i == 4 and item5 == "":
                item5 = new_item
                placed = True
                break
            if i == 5 and item6 == "":
                item6 = new_item
                placed = True
                break
            if i == 6 and item7 == "":
                item7 = new_item
                placed = True
                break
            if i == 7 and item8 == "":
                item8 = new_item
                placed = True
                break
            if i == 8 and item9 == "":
                item9 = new_item
                placed = True
                break
            if i == 9 and item10 == "":
                item10 = new_item
                placed = True
                break
            i = i + 1
        if placed:
            print("Item added!")
        else:
            print("Shopping list is full. Remove an item first.")

    elif choice == "2":  # View items
        print("Current items:")
        idx = 0
        while idx < 10:
            if idx == 0 and item1 != "":
                print(item1)
            if idx == 1 and item2 != "":
                print(item2)
            if idx == 2 and item3 != "":
                print(item3)
            if idx == 3 and item4 != "":
                print(item4)
            if idx == 4 and item5 != "":
                print(item5)
            if idx == 5 and item6 != "":
                print(item6)
            if idx == 6 and item7 != "":
                print(item7)
            if idx == 7 and item8 != "":
                print(item8)
            if idx == 8 and item9 != "":
                print(item9)
            if idx == 9 and item10 != "":
                print(item10)
            idx = idx + 1

    elif choice == "3":  # Remove item
        to_remove = input("Enter item to remove: ").strip()
        removed = False
        j = 0
        while j < 10:
            if j == 0 and item1 == to_remove:
                item1 = ""
                removed = True
                break
            if j == 1 and item2 == to_remove:
                item2 = ""
                removed = True
                break
            if j == 2 and item3 == to_remove:
                item3 = ""
                removed = True
                break
            if j == 3 and item4 == to_remove:
                item4 = ""
                removed = True
                break
            if j == 4 and item5 == to_remove:
                item5 = ""
                removed = True
                break
            if j == 5 and item6 == to_remove:
                item6 = ""
                removed = True
                break
            if j == 6 and item7 == to_remove:
                item7 = ""
                removed = True
                break
            if j == 7 and item8 == to_remove:
                item8 = ""
                removed = True
                break
            if j == 8 and item9 == to_remove:
                item9 = ""
                removed = True
                break
            if j == 9 and item10 == to_remove:
                item10 = ""
                removed = True
                break
            j = j + 1
        if removed:
            print("Item removed.")
        else:
            print("Item not found.")

    elif choice == "4":  # Count items
        total = 0
        k = 0
        while k < 10:
            if k == 0 and item1 != "":
                total = total + 1
            if k == 1 and item2 != "":
                total = total + 1
            if k == 2 and item3 != "":
                total = total + 1
            if k == 3 and item4 != "":
                total = total + 1
            if k == 4 and item5 != "":
                total = total + 1
            if k == 5 and item6 != "":
                total = total + 1
            if k == 6 and item7 != "":
                total = total + 1
            if k == 7 and item8 != "":
                total = total + 1
            if k == 8 and item9 != "":
                total = total + 1
            if k == 9 and item10 != "":
                total = total + 1
            k = k + 1
        print("Total items:", total)

    elif choice == "5":
        print("Goodbye!")
        running = False

    else:
        print("Invalid option. Please choose 1-5.")
# Out:
# === Shopping List Manager (CLEAN) ===
#
# 1. Add item
# 2. View items
# 3. Remove item
# 4. Count items
# 5. Exit
# Choose option: 1
# Enter item: noodles
# Item added!
#
# 1. Add item
# 2. View items
# 3. Remove item
# 4. Count items
# 5. Exit
# Choose option: 1
# Enter item: solo
# Item added!
#
# 1. Add item
# 2. View items
# 3. Remove item
# 4. Count items
# 5. Exit
# Choose option: 2
# Current items:
# noodles
# solo
#
# 1. Add item
# 2. View items
# 3. Remove item
# 4. Count items
# 5. Exit
# Choose option: 3
# Enter item to remove: solo
# Item removed.
#
# 1. Add item
# 2. View items
# 3. Remove item
# 4. Count items
# 5. Exit
# Choose option: 4
# Total items: 1
#
# 1. Add item
# 2. View items
# 3. Remove item
# 4. Count items
# 5. Exit
# Choose option: 5
# Goodbye!
